# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib widget

#############
## FORTRAN
#############

fx = np.loadtxt('../pbuild/outputs/xs.dat')
fB = np.loadtxt('../pbuild/outputs/B.dat')
fr = np.loadtxt('../pbuild/outputs/rho.dat')

# fx2 = np.loadtxt('../pbuild2/outputs/xs.dat')
# fB2 = np.loadtxt('../pbuild2/outputs/B.dat')
# fr2 = np.loadtxt('../pbuild2/outputs/rho.dat')


m = 5
xM = 50.0
r0 = 15

# print(len(fx2))

# %%
idx = -1
# frr = fr[idx, :] < 0


fig, axs = plt.subplots(1, 2, figsize = (13,5), sharex = True)

axs[0].plot(fx, fB[idx,:], '.-')
# axs[0].plot(fx[frr], fB[idx, frr], 'x')

axs[1].plot(fx, fr[idx,:], '.-')
# axs[1].plot(fx[frr], fr[idx, frr], 'x')

# axs[0].plot(fx2, fB2[idx,:], '.-')
# axs[0].plot(fx2[frr], fB2[idx, frr], 'x')

# axs[1].plot(fx2, fr2[idx,:], '.-')
# axs[1].plot(fx2[frr2], fr2[idx, frr2], 'x')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
