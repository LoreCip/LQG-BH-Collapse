# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib widget

#############
## FORTRAN
#############

pat = '/home/lorenzo/phd/LQG/Experiments/SplitConvergence/fixedMass/dx0.01/'


fx = np.loadtxt(pat + 'xs.dat')
fB = np.loadtxt(pat + 'B.dat')
fE = np.loadtxt(pat + 'E.dat')
fr = np.loadtxt(pat + 'rho.dat')

# fx_s = np.loadtxt('../build_simm/outputs/xs.dat')
# fB_s = np.loadtxt('../build_simm/outputs/B.dat')
# fE_s = np.loadtxt('../build_simm/outputs/E.dat')
# fr_s = np.loadtxt('../build_simm/outputs/rho.dat')

m = 5
xM = 50.0
r0 = 15

# print(len(fx2))

# %%
fig, axs = plt.subplots(1, 3, figsize = (13,5), sharex = True)
# for idx in range(len(fr)):
for idx in [-1]:
    axs[0].plot(fx, fB[idx, :],      label = "OG")
    axs[1].plot(fx, fE[idx, :],      label = "OG")
    axs[2].plot(fx[10:], fr[idx, 10:], '.-',    label = "OG")

    # axs[0].plot(fx_s, fB_s[idx, :],    '--', label = "Symm")
    # axs[1].plot(fx_s, fE_s[idx, :],    '--', label = "Symm")
    # axs[2].plot(fx_s[:], fr_s[idx, :], '--', label = "Symm")

axs[0].set_ylabel("B")
axs[1].set_ylabel(r"$\epsilon^b$")
axs[2].set_ylabel(r"$\rho$")

plt.tight_layout()
print(idx)
plt.legend();
# Out:
# -1
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
