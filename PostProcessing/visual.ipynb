# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib widget

#############
## FORTRAN
#############

fx = np.loadtxt('../build/outputs/xs.dat')
fB = np.loadtxt('../build/outputs/B.dat')
fE = np.loadtxt('../build/outputs/E.dat')
fr = np.loadtxt('../build/outputs/rho.dat')

# fx2 = np.loadtxt('../pbuild2/outputs/xs.dat')
# fB2 = np.loadtxt('../pbuild2/outputs/B.dat')
# fr2 = np.loadtxt('../pbuild2/outputs/rho.dat')


m = 5
xM = 50.0
r0 = 15

# print(len(fx2))

# %%
fig, axs = plt.subplots(1, 3, figsize = (13,5), sharex = True)
# for idx in range(len(fr)):
for idx in [0]:
    axs[0].plot(fx, fB[:], label = idx)
    axs[1].plot(fx, fE[:], label = idx)
    axs[2].plot(fx[10:], fr[10:], label = idx)

plt.legend()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fr = np.loadtxt('../test.dat')

# %%
fig = plt.figure()
plt.plot(np.linspace(-1,1, 10000), fr)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fr
# Out:
# array([3.12159232e+00, 3.11330744e+00, 3.10694991e+00, ...,
#        2.82870002e-02, 2.00028593e-02, 3.17881267e-04])
