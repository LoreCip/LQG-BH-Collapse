# %%
import readSim as rs
import numpy as np

s = rs.Sim('/home/lorenzo/phd/LQG/ClosedUniverse_TimeVSa0/id0_m5.0_dx0.01_xMax70.0_tf350.0_r010.0_a060.0_corrected')

# %%
s.plot('rho', iteration=0, xrange=(2, 15), showHor=True)
